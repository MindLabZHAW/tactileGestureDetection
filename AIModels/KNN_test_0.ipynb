# %%
# KNN
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Load data
data_path = '../DATA/labeled_window_dataset.csv'
df = pd.read_csv(data_path)

# Group by 'block_id' and calculate mean of each feature
grouped_df = df.groupby('window_id').apply(np.mean)

# Extract labels
labels = df.groupby('window_id')['window_touch_type'].first()

# Prepare feature matrix X and label vector y
X = grouped_df.drop(columns=['window_id']).values  # Drop 'block_id' from features
y = labels.values

# Encode labels
label_classes = np.unique(y)
label_map = {label: idx for idx, label in enumerate(label_classes)}
y_encoded = np.array([label_map[label] for label in y])

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.3, random_state=42)

# Initialize KNN classifier
knn = KNeighborsClassifier()

# Define hyperparameters grid
param_grid = {
    'n_neighbors': list(range(1, 21)),  # 搜索1到20范围内的邻居数
    'weights': ['uniform', 'distance']  # 搜索'weights'参数中的两种不同模式
}


# Initialize GridSearchCV
grid_search = GridSearchCV(knn, param_grid, cv=5, scoring='accuracy')

# Fit GridSearchCV
grid_search.fit(X_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_
print(f'Best parameters: {best_params}')

# Train KNN classifier with the best parameters
best_knn = grid_search.best_estimator_

# Perform cross-validation on the training set
cv_scores = cross_val_score(best_knn,X_train,y_train,cv = 5)

# Predict
y_pred = best_knn.predict(X_test)

# Evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')

# Print predicted and true labels
print(f'Predicted labels: {y_pred}')
print(f'True labels: {y_test}')

# Display classification report
print(classification_report(y_test, y_pred, target_names=label_classes))

conf_matrix = confusion_matrix(y_test,y_pred)

#plot confusion matrix using seabon
plt.figure()
sns.heatmap(conf_matrix,annot=True,fmt= 'd',cmap='Blues', xticklabels=label_classes, yticklabels=label_classes)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1353, in GroupBy.apply(self, func, *args, **kwargs)
#    1352 try:
# -> 1353     result = self._python_apply_general(f, self._selected_obj)
#    1354 except TypeError:
#    1355     # gh-20949
#    1356     # try again, with .apply acting as a filtering
#    (...)
#    1360     # fails on *some* columns, e.g. a numeric operation
#    1361     # on a string grouper column
#
# File ~/miniconda/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1402, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1376 """
#    1377 Apply function f in python space
#    1378
#    (...)
#    1400     data after applying f
#    1401 """
# -> 1402 values, mutated = self.grouper.apply(f, data, self.axis)
#    1403 if not_indexed_same is None:
#
# File ~/miniconda/lib/python3.8/site-packages/pandas/core/groupby/ops.py:767, in BaseGrouper.apply(self, f, data, axis)
#     766 group_axes = group.axes
# --> 767 res = f(group)
#     768 if not mutated and not _is_indexed_like(res, group_axes, axis):
#
# File <__array_function__ internals>:200, in mean(*args, **kwargs)
#
# File ~/miniconda/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3462, in mean(a, axis, dtype, out, keepdims, where)
#    3461     else:
# -> 3462         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3464 return _methods._mean(a, axis=axis, dtype=dtype,
#    3465                       out=out, **kwargs)
#
# File ~/miniconda/lib/python3.8/site-packages/pandas/core/generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/miniconda/lib/python3.8/site-packages/pandas/core/generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File ~/miniconda/lib/python3.8/site-packages/pandas/core/generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File ~/miniconda/lib/python3.8/site-packages/pandas/core/frame.py:10498, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10497 if axis is None:
# > 10498     return func(df.values)
#   10499 elif axis == 1:
#
# File ~/miniconda/lib/python3.8/site-packages/pandas/core/frame.py:10472, in DataFrame._reduce.<locals>.func(values)
#   10470 def func(values: np.ndarray):
#   10471     # We only use this in the case that operates on self.values
# > 10472     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File ~/miniconda/lib/python3.8/site-packages/pandas/core/nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#
# File ~/miniconda/lib/python3.8/site-packages/pandas/core/nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File ~/miniconda/lib/python3.8/site-packages/pandas/core/nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     419     mask = isna(values)
# --> 421 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     423 if datetimelike:
#
# File ~/miniconda/lib/python3.8/site-packages/pandas/core/nanops.py:727, in nanmean(values, axis, skipna, mask)
#     726 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     729 if axis is not None and getattr(the_sum, "ndim", False):
#
# File ~/miniconda/lib/python3.8/site-packages/numpy/core/_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 16
#      13 df = pd.read_csv(data_path)
#      15 # Group by 'block_id' and calculate mean of each feature
# ---> 16 grouped_df = df.groupby('window_id').apply(np.mean)
#      18 # Extract labels
#      19 labels = df.groupby('window_id')['window_touch_type'].first()
#
# File ~/miniconda/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1363, in GroupBy.apply(self, func, *args, **kwargs)
#    1353         result = self._python_apply_general(f, self._selected_obj)
#    1354     except TypeError:
#    1355         # gh-20949
#    1356         # try again, with .apply acting as a filtering
#    (...)
#    1360         # fails on *some* columns, e.g. a numeric operation
#    1361         # on a string grouper column
# -> 1363         return self._python_apply_general(f, self._obj_with_exclusions)
#    1365 return result
#
# File ~/miniconda/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1402, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1367 @final
#    1368 def _python_apply_general(
#    1369     self,
#    (...)
#    1374     is_agg: bool = False,
#    1375 ) -> NDFrameT:
#    1376     """
#    1377     Apply function f in python space
#    1378
#    (...)
#    1400         data after applying f
#    1401     """
# -> 1402     values, mutated = self.grouper.apply(f, data, self.axis)
#    1403     if not_indexed_same is None:
#    1404         not_indexed_same = mutated
#
# File ~/miniconda/lib/python3.8/site-packages/pandas/core/groupby/ops.py:767, in BaseGrouper.apply(self, f, data, axis)
#     765 # group might be modified
#     766 group_axes = group.axes
# --> 767 res = f(group)
#     768 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     769     mutated = True
#
# File <__array_function__ internals>:200, in mean(*args, **kwargs)
#
# File ~/miniconda/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3462, in mean(a, axis, dtype, out, keepdims, where)
#    3460         pass
#    3461     else:
# -> 3462         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3464 return _methods._mean(a, axis=axis, dtype=dtype,
#    3465                       out=out, **kwargs)
#
# File ~/miniconda/lib/python3.8/site-packages/pandas/core/generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/miniconda/lib/python3.8/site-packages/pandas/core/generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File ~/miniconda/lib/python3.8/site-packages/pandas/core/generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File ~/miniconda/lib/python3.8/site-packages/pandas/core/frame.py:10498, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10496     df = _get_data()
#   10497 if axis is None:
# > 10498     return func(df.values)
#   10499 elif axis == 1:
#   10500     if len(df.index) == 0:
#   10501         # Taking a transpose would result in no columns, losing the dtype.
#   10502         # In the empty case, reducing along axis 0 or 1 gives the same
#   10503         # result dtype, so reduce with axis=0 and ignore values
#
# File ~/miniconda/lib/python3.8/site-packages/pandas/core/frame.py:10472, in DataFrame._reduce.<locals>.func(values)
#   10470 def func(values: np.ndarray):
#   10471     # We only use this in the case that operates on self.values
# > 10472     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File ~/miniconda/lib/python3.8/site-packages/pandas/core/nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File ~/miniconda/lib/python3.8/site-packages/pandas/core/nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     156         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File ~/miniconda/lib/python3.8/site-packages/pandas/core/nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     418 if datetimelike and mask is None:
#     419     mask = isna(values)
# --> 421 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     423 if datetimelike:
#     424     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/miniconda/lib/python3.8/site-packages/pandas/core/nanops.py:727, in nanmean(values, axis, skipna, mask)
#     724     dtype_count = dtype
#     726 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     729 if axis is not None and getattr(the_sum, "ndim", False):
#     730     count = cast(np.ndarray, count)
#
# File ~/miniconda/lib/python3.8/site-packages/numpy/core/_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'
