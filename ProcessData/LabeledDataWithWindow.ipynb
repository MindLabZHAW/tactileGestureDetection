# %%
import os
import pandas as pd

global_window_id = 0  # 用于标识每个窗口的全局唯一ID

# 读取 tactile_dataset.csv 并提取数据块信息
def load_tactile_dataset(tactile_dataset_file):
    """加载 tactile_dataset.csv 文件并提取数据块信息"""
    if os.path.isfile(tactile_dataset_file):
        df = pd.read_csv(tactile_dataset_file)
        # 提取每个数据块的信息
        block_info = df.groupby('block_id').apply(
            lambda x: (x.name, x.index[0], x.index[-1], x['touch_type'].iloc[0])
        ).tolist()
        return block_info
    else:
        raise FileNotFoundError(f"未找到文件 {tactile_dataset_file}")

def check_overlap(window_df, block_info):
    """检查窗口数据块是否与tactile_dataset.csv中的数据块有重叠"""
    overlap_blocks = []
    window_start = window_df.index[0]
    window_end = window_df.index[-1]

    for block_id, block_start, block_end, block_touch_type in block_info:
        # Check for any overlap (Partial Overlap)
        if (window_end >= block_start) and (window_start <= block_end):
            overlap_blocks.append((block_id, block_touch_type))

        # Check if the window is completely within the block (Complete Containment: Window in Block)
        elif (window_start >= block_start) and (window_end <= block_end):
            overlap_blocks.append((block_id, block_touch_type))

        # Check if the block is completely within the window (Complete Containment: Block in Window)
        elif (block_start >= window_start) and (block_end <= window_end):
            overlap_blocks.append((block_id, block_touch_type))

    return overlap_blocks

def process_labeled_data(file_path, block_info, window_size=28, step_size=14):
    global global_window_id
    df = pd.read_csv(file_path)
    windows = []

    # 滑动窗口切割
    for start in range(0, len(df) - window_size + 1, step_size):
        end = start + window_size
        window_df = df.iloc[start:end].copy()  # 切割窗口

        # 检查窗口是否与 tactile_dataset.csv 的任何数据块重叠
        overlap_blocks = check_overlap(window_df, block_info)

        # 如果有重叠
        if overlap_blocks:
            block_ids, touch_types = zip(*overlap_blocks)
            window_df['block_id'] = ','.join(map(str, block_ids))  # 记录重叠的 block_id
            window_df['touch_type'] = ','.join(touch_types)  # 记录重叠的 touch_type
        else:
            window_df['block_id'] = 'NA'  # 没有重叠则标记为 NA
            window_df['touch_type'] = 'NC'  # 没有重叠则标记为 NC (No Contact)

        window_df['window_id'] = global_window_id  # 为每个窗口分配全局唯一ID
        windows.append(window_df)
        global_window_id += 1  # 增加全局窗口ID
    
    return windows

def process_all_folders(data_folder, tactile_dataset_path, output_file, window_size, step_size):
    """处理所有子文件夹，生成带有窗口标记的新 CSV 文件"""
    block_info = load_tactile_dataset(tactile_dataset_path)
    all_windows = []

    for folder_name in os.listdir(data_folder):
        folder_path = os.path.join(data_folder, folder_name)
        if os.path.isdir(folder_path):
            file_path = os.path.join(folder_path, 'labeled_data.csv')
            if os.path.isfile(file_path):
                windows = process_labeled_data(file_path, block_info, window_size, step_size)
                all_windows.extend(windows)

    if all_windows:
        result_df = pd.concat(all_windows, ignore_index=True)
        output_path = os.path.join(output_file, 'windowed_dataset.csv')
        
        # 如果文件存在则删除
        if os.path.exists(output_path):
            os.remove(output_path)
        
        result_df.to_csv(output_path, index=False)
        print(f"windowed_dataset.csv 文件已生成，包含 {len(all_windows)} 个窗口")
    else:
        print("没有数据块被处理")

# %%
data_folder = '../DATA/Labeled_data'
tactile_dataset_path='../DATA/tactile_dataset.csv'
output_file = '../DATA/'
window_size = 28
step_size = 14  # 前移步长

# 处理所有文件夹并生成最终输出
process_all_folders(data_folder, tactile_dataset_path, output_file, window_size, step_size)
# Out:
# windowed_dataset.csv 文件已生成，包含 13987 个窗口

# %%
# 先验证文件总行数是否一致，应是原来数据行数的两倍
data_folder = '../DATA/Labeled_data'
total_row = 0
for folder_name in os.listdir(data_folder):
    folder_path = os.path.join(data_folder,folder_name)
    file_path = os.path.join(folder_path,'labeled_data.csv')
    print(f"当前路径是：{file_path}")

    if os.path.isfile(file_path):
        df = pd.read_csv(file_path)
        row_count = len(df)
        print(f"当前文件共有{row_count}行")
        total_row += row_count
        print(f"目前共有{total_row} 行")
print(f"共有{total_row} 行")
# Out:
# 当前路径是：../DATA/Labeled_data/0724-7DT-Y1/labeled_data.csv
# 当前文件共有23022行
# 目前共有23022 行
# 当前路径是：../DATA/Labeled_data/0724-7ST-Y1/labeled_data.csv
# 当前文件共有30682行
# 目前共有53704 行
# 当前路径是：../DATA/Labeled_data/0724-7ST-S1/labeled_data.csv
# 当前文件共有20499行
# 目前共有74203 行
# 当前路径是：../DATA/Labeled_data/0724-7DT-S1/labeled_data.csv
# 当前文件共有23775行
# 目前共有97978 行
# 当前路径是：../DATA/Labeled_data/0724-7P-Y1/labeled_data.csv
# 当前文件共有26122行
# 目前共有124100 行
# 当前路径是：../DATA/Labeled_data/0724-7P-S1/labeled_data.csv
# 当前文件共有18024行
# 目前共有142124 行
# 当前路径是：../DATA/Labeled_data/0724-7G-S1/labeled_data.csv
# 当前文件共有22884行
# 目前共有165008 行
# 当前路径是：../DATA/Labeled_data/0724-7G-Y1/labeled_data.csv
# 当前文件共有30971行
# 目前共有195979 行
# 共有195979 行

# %%
#验证

window_data= pd.read_csv("/Users/shangyu/Documents/GitHub/tactileGestureDetection/DATA/windowed_dataset.csv")
window_data
# # window_data.head()
grouped_data = window_data.groupby(['window_id','block_id'])
grouped_data
for name, group in grouped_data:
    print(f"Group name: {name}")
    # print(group)

# contact_count = window_data['block_id'].unique()
# contact_count
# print(f"there are {len(contact_count)} contact block") # 453-511=58 少了58个contact block, 为什么？

# filtered = window_data[window_data['block_id'] =='NA']
# filtered
# Out:
# Group name: (0, '0')
# Group name: (1, '0,1')
# Group name: (2, '0,1')
# Group name: (3, '1,2')
# Group name: (4, '1,2')
# Group name: (5, '2')
# Group name: (6, '2,3')
# Group name: (7, '2,3')
# Group name: (8, '3')
# Group name: (9, '3,4')
# Group name: (10, '3,4')
# Group name: (11, '4')
# Group name: (12, '4,5')
# Group name: (13, '4,5')
# Group name: (14, '5')
# Group name: (15, '5,6')
# Group name: (16, '5,6')
# Group name: (17, '6,7')
# Group name: (18, '6,7')
# Group name: (19, '7')
# Group name: (20, '7,8')
# Group name: (21, '7,8')
# Group name: (22, '8,9')
# Group name: (23, '8,9')
# Group name: (24, '9')
# Group name: (25, '9,10')
# Group name: (26, '9,10')
# Group name: (27, '10,11')
# Group name: (28, '10,11')
# Group name: (29, '11,12')
# Group name: (30, '11,12')
# Group name: (31, '12')
# Group name: (32, '12,13')
# Group name: (33, '12,13')
# Group name: (34, '13')
# Group name: (35, '13,14')
# Group name: (36, '13,14')
# Group name: (37, '14')
# Group name: (38, '14,15')
# Group name: (39, '15')
# Group name: (40, '15,16')
# Group name: (41, '15,16')
# Group name: (42, '16')
# Group name: (43, '16,17')
# Group name: (44, '16,17')
# Group name: (45, '17')
# Group name: (46, '17,18')
# Group name: (47, '17,18')
# Group name: (48, '18')
# Group name: (49, '18,19')
# Group name: (50, '18,19')
# Group name: (51, '19')
# Group name: (52, '19,20')
# Group name: (53, '19,20')
# Group name: (54, '20')
# Group name: (55, '20,21')
# Group name: (56, '21')
# Group name: (57, '21,22')
# Group name: (58, '21,22')
# Group name: (59, '22')
# Group name: (60, '22,23')
# Group name: (61, '22,23')
# Group name: (62, '23')
# Group name: (63, '23,24')
# Group name: (64, '23,24')
# Group name: (65, '24')
# Group name: (66, '24,25')
# Group name: (67, '24,25')
# Group name: (68, '25')
# Group name: (69, '25,26')
# Group name: (70, '25,26')
# Group name: (71, '26,27')
# Group name: (72, '26,27')
# Group name: (73, '27')
# Group name: (74, '27,28')
# Group name: (75, '27,28')
# Group name: (76, '28')
# Group name: (77, '28,29')
# Group name: (78, '28,29')
# Group name: (79, '29')
# Group name: (80, '29,30')
# Group name: (81, '29,30')
# Group name: (82, '30')
# Group name: (83, '30,31')
# Group name: (84, '30,31')
# Group name: (85, '31')
# Group name: (86, '31,32')
# Group name: (87, '31,32')
# Group name: (88, '32')
# Group name: (89, '32,33')
# Group name: (90, '32,33')
# Group name: (91, '33')
# Group name: (92, '33,34')
# Group name: (93, '33,34')
# Group name: (94, '34')
# Group name: (95, '34,35')
# Group name: (96, '34,35')
# Group name: (97, '35')
# Group name: (98, '35,36')
# Group name: (99, '35,36')
# Group name: (100, '36')
# Group name: (101, '36,37')
# Group name: (102, '36,37')
# Group name: (103, '37')
# Group name: (104, '37,38')
# Group name: (105, '37,38')
# Group name: (106, '38')
# Group name: (107, '38,39')
# Group name: (108, '38,39')
# Group name: (109, '39')
# Group name: (110, '39,40')
# Group name: (111, '39,40')
# Group name: (112, '40')
# Group name: (113, '40,41')
# Group name: (114, '41')
# Group name: (115, '41')
# Group name: (116, '41,42')
# Group name: (117, '41,42')
# Group name: (118, '42')
# Group name: (119, '42,43')
# Group name: (120, '42,43')
# Group name: (121, '43')
# Group name: (122, '43,44')
# Group name: (123, '43,44')
# Group name: (124, '44')
# Group name: (125, '44,45')
# Group name: (126, '44,45')
# Group name: (127, '45')
# Group name: (128, '45,46')
# Group name: (129, '45,46')
# Group name: (130, '46')
# Group name: (131, '46,47')
# Group name: (132, '46,47')
# Group name: (133, '47')
# Group name: (134, '47,48')
# Group name: (135, '47,48')
# Group name: (136, '48')
# Group name: (137, '48,49')
# Group name: (138, '48,49')
# Group name: (139, '49')
# Group name: (140, '49,50')
# Group name: (141, '49,50')
# Group name: (142, '50')
# Group name: (143, '50,51')
# Group name: (144, '50,51')
# Group name: (145, '51')
# Group name: (146, '51,52')
# Group name: (147, '51,52')
# Group name: (148, '52')
# Group name: (149, '52,53')
# Group name: (150, '52,53')
# Group name: (151, '53')
# Group name: (152, '53,54')
# Group name: (153, '53,54')
# Group name: (154, '54')
# Group name: (155, '54,55')
# Group name: (156, '54,55')
# Group name: (157, '55')
# Group name: (158, '55,56')
# Group name: (159, '55,56')
# Group name: (160, '56')
# Group name: (161, '56')
# Group name: (162, '56,57')
# Group name: (163, '56,57')
# Group name: (164, '57')
# Group name: (165, '57,58')
# Group name: (166, '57,58')
# Group name: (167, '58')
# Group name: (168, '58,59')
# Group name: (169, '58,59')
# Group name: (170, '59')
# Group name: (171, '59,60,61')
# Group name: (172, '60,61,62,63')
# Group name: (173, '61,62,63,64')
# Group name: (174, '63,64,65,66')
# Group name: (175, '65,66,67')
# Group name: (176, '66,67,68,69')
# Group name: (177, '67,68,69,70')
# Group name: (178, '69,70,71')
# Group name: (179, '70,71,72,73')
# Group name: (180, '72,73,74,75')
# Group name: (181, '73,74,75,76')
# Group name: (182, '75,76,77')
# Group name: (183, '76,77')
# Group name: (184, '77,78')
# Group name: (185, '78,79')
# Group name: (186, '78,79,80')
# Group name: (187, '79,80,81')
# Group name: (188, '80,81,82,83')
# Group name: (189, '81,82,83,84')
# Group name: (190, '83,84,85,86')
# Group name: (191, '84,85,86,87')
# Group name: (192, '86,87,88')
# Group name: (193, '87,88,89')
# Group name: (194, '88,89,90')
# Group name: (195, '89,90,91')
# Group name: (196, '90,91,92')
# Group name: (197, '91,92,93')
# Group name: (198, '92,93')
# Group name: (199, '93,94')
# Group name: (200, '93,94,95')
# Group name: (201, '94,95,96')
# Group name: (202, '95,96,97,98')
# Group name: (203, '96,97,98,99')
# Group name: (204, '98,99,100')
# Group name: (205, '99,100,101,102')
# Group name: (206, '100,101,102')
# Group name: (207, '102,103,104')
# Group name: (208, '102,103,104,105')
# Group name: (209, '104,105,106')
# Group name: (210, '105,106,107')
# Group name: (211, '106,107')
# Group name: (212, '107,108')
# Group name: (213, '108,109')
# Group name: (214, '108,109')
# Group name: (215, '109,110')
# Group name: (216, '109,110,111,112')
# Group name: (217, '110,111,112')
# Group name: (218, '112,113')
# Group name: (219, '112,113,114')
# Group name: (220, '113,114')
# Group name: (221, '114,115')
# Group name: (222, '115,116')
# Group name: (223, '115,116,117')
# Group name: (224, '116,117,118')
# Group name: (225, '117,118')
# Group name: (226, '118,119,120')
# Group name: (227, '119,120')
# Group name: (228, '120,121')
# Group name: (229, '121,122')
# Group name: (230, '121,122,123')
# Group name: (231, '122,123,124')
# Group name: (232, '123,124,125')
# Group name: (233, '124,125,126')
# Group name: (234, '125,126,127')
# Group name: (235, '126,127,128')
# Group name: (236, '127,128')
# Group name: (237, '128,129,130,131')
# Group name: (238, '129,130,131,132')
# Group name: (239, '131,132,133')
# Group name: (240, '132,133,134')
# Group name: (241, '133,134,135')
# Group name: (242, '134,135')
# Group name: (243, '135,136')
# Group name: (244, '135,136,137')
# Group name: (245, '136,137,138,139')
# Group name: (246, '137,138,139,140')
# Group name: (247, '139,140,141')
# Group name: (248, '140,141,142')
# Group name: (249, '141,142,143')
# Group name: (250, '142,143,144')
# Group name: (251, '143,144,145,146')
# Group name: (252, '144,145,146,147')
# Group name: (253, '146,147,148')
# Group name: (254, '147,148,149')
# Group name: (255, '148,149,150,151')
# Group name: (256, '149,150,151,152')
# Group name: (257, '151,152,153')
# Group name: (258, '152,153,154,155')
# Group name: (259, '153,154,155')
# Group name: (260, '155,156,157,158')
# Group name: (261, '156,157,158')
# Group name: (262, '158,159')
# Group name: (263, '158,159,160')
# Group name: (264, '159,160,161,162,163')
# Group name: (265, '160,161,162,163,164')
# Group name: (266, '163,164,165')
# Group name: (267, '164,165,166,167,168,169')
# Group name: (268, '166,167,168,169,170')
# Group name: (269, '169,170,171')
# Group name: (270, '170,171,172')
# Group name: (271, '171,172,173')
# Group name: (272, '172,173,174')
# Group name: (273, '173,174,175')
# Group name: (274, '174,175,176')
# Group name: (275, '175,176,177,178')
# Group name: (276, '176,177,178,179')
# Group name: (277, '178,179,180')
# Group name: (278, '179,180,181')
# Group name: (279, '180,181,182,183')
# Group name: (280, '181,182,183,184')
# Group name: (281, '183,184,185')
# Group name: (282, '184,185')
# Group name: (283, '185')
# Group name: (284, '185,186')
# Group name: (285, '185,186')
# Group name: (286, '186,187')
# Group name: (287, '186,187')
# Group name: (288, '187,188')
# Group name: (289, '187,188')
# Group name: (290, '188')
# Group name: (291, '188,189')
# Group name: (292, '188,189')
# Group name: (293, '189')
# Group name: (294, '189,190')
# Group name: (295, '189,190')
# Group name: (296, '190,191')
# Group name: (297, '190,191')
# Group name: (298, '191')
# Group name: (299, '191,192')
# Group name: (300, '191,192')
# Group name: (301, '192,193')
# Group name: (302, '192,193')
# Group name: (303, '193')
# Group name: (304, '193,194')
# Group name: (305, '193,194')
# Group name: (306, '194,195')
# Group name: (307, '194,195')
# Group name: (308, '195')
# Group name: (309, '195,196')
# Group name: (310, '195,196')
# Group name: (311, '196')
# Group name: (312, '196,197')
# Group name: (313, '196,197')
# Group name: (314, '197')
# Group name: (315, '197,198')
# Group name: (316, '197,198')
# Group name: (317, '198,199')
# Group name: (318, '198,199')
# Group name: (319, '199')
# Group name: (320, '199,200')
# Group name: (321, '199,200')
# Group name: (322, '200,201')
# Group name: (323, '200,201')
# Group name: (324, '201')
# Group name: (325, '201,202')
# Group name: (326, '201,202')
# Group name: (327, '202,203')
# Group name: (328, '202,203')
# Group name: (329, '203')
# Group name: (330, '203,204')
# Group name: (331, '203,204')
# Group name: (332, '204')
# Group name: (333, '204,205')
# Group name: (334, '205')
# Group name: (335, '205')
# Group name: (336, '205,206')
# Group name: (337, '206')
# Group name: (338, '206,207')
# Group name: (339, '206,207')
# Group name: (340, '207,208')
# Group name: (341, '207,208')
# Group name: (342, '208,209')
# Group name: (343, '208,209')
# Group name: (344, '209')
# Group name: (345, '209')
# Group name: (346, '209,210')
# Group name: (347, '209,210')
# Group name: (348, '210,211')
# Group name: (349, '210,211')
# Group name: (350, '211')
# Group name: (351, '211,212')
# Group name: (352, '211,212')
# Group name: (353, '212,213')
# Group name: (354, '212,213')
# Group name: (355, '213')
# Group name: (356, '213,214')
# Group name: (357, '213,214')
# Group name: (358, '214')
# Group name: (359, '214,215')
# Group name: (360, '214,215')
# Group name: (361, '215')
# Group name: (362, '215,216')
# Group name: (363, '215,216')
# Group name: (364, '216')
# Group name: (365, '216,217')
# Group name: (366, '216,217')
# Group name: (367, '217')
# Group name: (368, '217,218')
# Group name: (369, '217,218')
# Group name: (370, '218,219')
# Group name: (371, '218,219')
# Group name: (372, '219')
# Group name: (373, '219,220')
# Group name: (374, '219,220')
# Group name: (375, '220')
# Group name: (376, '220,221')
# Group name: (377, '220,221')
# Group name: (378, '221')
# Group name: (379, '221')
# Group name: (380, '221,222')
# Group name: (381, '221,222')
# Group name: (382, '222')
# Group name: (383, '222,223')
# Group name: (384, '222,223')
# Group name: (385, '223,224')
# Group name: (386, '223,224')
# Group name: (387, '224')
# Group name: (388, '224,225')
# Group name: (389, '224,225')
# Group name: (390, '225')
# Group name: (391, '225,226')
# Group name: (392, '225,226')
# Group name: (393, '226')
# Group name: (394, '226,227')
# Group name: (395, '226,227')
# Group name: (396, '227')
# Group name: (397, '227,228')
# Group name: (398, '227,228')
# Group name: (399, '228')
# Group name: (400, '228,229')
# Group name: (401, '228,229')
# Group name: (402, '229')
# Group name: (403, '229,230')
# Group name: (404, '229,230')
# Group name: (405, '230,231')
# Group name: (406, '230,231')
# Group name: (407, '231')
# Group name: (408, '231')
# Group name: (409, '231,232')
# Group name: (410, '231,232')
# Group name: (411, '232')
# Group name: (412, '232,233')
# Group name: (413, '232,233')
# Group name: (414, '233')
# Group name: (415, '233,234')
# Group name: (416, '233,234')
# Group name: (417, '234')
# Group name: (418, '234,235')
# Group name: (419, '234,235')
# Group name: (420, '235')
# Group name: (421, '235')
# Group name: (422, '235,236')
# Group name: (423, '235,236')
# Group name: (424, '236,237')
# Group name: (425, '236,237')
# Group name: (426, '237')
# Group name: (427, '237,238')
# Group name: (428, '237,238')
# Group name: (429, '238')
# Group name: (430, '238')
# Group name: (431, '238,239')
# Group name: (432, '238,239')
# Group name: (433, '239')
# Group name: (434, '239,240')
# Group name: (435, '239,240')
# Group name: (436, '240')
# Group name: (437, '240')
# Group name: (438, '240,241')
# Group name: (439, '241')
# Group name: (440, '241')
# Group name: (441, '241,242')
# Group name: (442, '242')
# Group name: (443, '242,243')
# Group name: (444, '242,243')
# Group name: (445, '243')
# Group name: (446, '243,244')
# Group name: (447, '243,244')
# Group name: (448, '244')
# Group name: (449, '244,245')
# Group name: (450, '244,245')
# Group name: (451, '245,246')
# Group name: (452, '245,246')
# Group name: (453, '246,247')
# Group name: (454, '246,247')
# Group name: (455, '247,248')
# Group name: (456, '247,248,249')
# Group name: (457, '249')
# Group name: (458, '249,250')
# Group name: (459, '249,250')
# Group name: (460, '250')
# Group name: (461, '250,251')
# Group name: (462, '250,251')
# Group name: (463, '251')
# Group name: (464, '251,252')
# Group name: (465, '251,252')
# Group name: (466, '252')
# Group name: (467, '252')
# Group name: (468, '252')
# Group name: (469, '252')
# Group name: (470, '252')
# Group name: (471, '252,253')
# Group name: (472, '253')
# Group name: (473, '253,254')
# Group name: (474, '253,254,255')
# Group name: (475, '254,255')
# Group name: (476, '255,256')
# Group name: (477, '255,256')
# Group name: (478, '256')
# Group name: (479, '256')
# Group name: (480, '256,257')
# Group name: (481, '256,257')
# Group name: (482, '257')
# Group name: (483, '257')
# Group name: (484, '257,258,259')
# Group name: (485, '257,258,259')
# Group name: (486, '259')
# Group name: (487, '259,260,261,262')
# Group name: (488, '259,260,261,262')
# Group name: (489, '262,263')
# Group name: (490, '262,263')
# Group name: (491, '263')
# Group name: (492, '263,264')
# Group name: (493, '263,264')
# Group name: (494, '264,265')
# Group name: (495, '264,265')
# Group name: (496, '265')
# Group name: (497, '265,266')
# Group name: (498, '265,266,267')
# Group name: (499, '266,267')
# Group name: (500, '267,268')
# Group name: (501, '267,268')
# Group name: (502, '268,269')
# Group name: (503, '268,269')
# Group name: (504, '269,270')
# Group name: (505, '269,270')
# Group name: (506, '270')
# Group name: (507, '270')
# Group name: (508, '270')
# Group name: (509, '270')
# Group name: (510, '270,271')
# Group name: (511, '270,271')
# Group name: (512, '271')
# Group name: (513, '271,272')
# Group name: (514, '271,272')
# Group name: (515, '272,273')
# Group name: (516, '272,273')
# Group name: (517, '273,274')
# Group name: (518, '273,274')
# Group name: (519, '274')
# Group name: (520, '274,275')
# Group name: (521, '274,275')
# Group name: (522, '275')
# Group name: (523, '275')
# Group name: (524, '275,276')
# Group name: (525, '275,276')
# Group name: (526, '276')
# Group name: (527, '276')
# Group name: (528, '276')
# Group name: (529, '276,277')
# Group name: (530, '276,277')
# Group name: (531, '277')
# Group name: (532, '277,278')
# Group name: (533, '277,278')
# Group name: (534, '278')
# Group name: (535, '278')
# Group name: (536, '278')
# Group name: (537, '278,279')
# Group name: (538, '278,279')
# Group name: (539, '279')
# Group name: (540, '279')
# Group name: (541, '279')
# Group name: (542, '279,280')
# Group name: (543, '279,280')
# Group name: (544, '280')
# Group name: (545, '280')
# Group name: (546, '280')
# Group name: (547, '280')
# Group name: (548, '280,281')
# Group name: (549, '281')
# Group name: (550, '281')
# Group name: (551, '281,282')
# Group name: (552, '281,282')
# Group name: (553, '282')
# Group name: (554, '282')
# Group name: (555, '282')
# Group name: (556, '282,283')
# Group name: (557, '282,283')
# Group name: (558, '283,284')
# Group name: (559, '283,284,285')
# Group name: (560, '285')
# Group name: (561, '285,286,287')
# Group name: (562, '285,286,287')
# Group name: (563, '287')
# Group name: (564, '287')
# Group name: (565, '287,288')
# Group name: (566, '287,288')
# Group name: (567, '288')
# Group name: (568, '288,289')
# Group name: (569, '288,289')
# Group name: (570, '289')
# Group name: (571, '289')
# Group name: (572, '289,290')
# Group name: (573, '289,290')
# Group name: (574, '290')
# Group name: (575, '290,291')
# Group name: (576, '290,291')
# Group name: (577, '291')
# Group name: (578, '291')
# Group name: (579, '291,292')
# Group name: (580, '291,292')
# Group name: (581, '292')
# Group name: (582, '292')
# Group name: (583, '292,293')
# Group name: (584, '292,293')
# Group name: (585, '293')
# Group name: (586, '293')
# Group name: (587, '293,294')
# Group name: (588, '293,294')
# Group name: (589, '294')
# Group name: (590, '294')
# Group name: (591, '294')
# Group name: (592, '294,295')
# Group name: (593, '294,295')
# Group name: (594, '295')
# Group name: (595, '295,296')
# Group name: (596, '295,296')
# Group name: (597, '296')
# Group name: (598, '296')
# Group name: (599, '296')
# Group name: (600, '296,297,298')
# Group name: (601, '296,297,298')
# Group name: (602, '298')
# Group name: (603, '298')
# Group name: (604, '298')
# Group name: (605, '298,299,300')
# Group name: (606, '298,299,300')
# Group name: (607, '300')
# Group name: (608, '300')
# Group name: (609, '300,301')
# Group name: (610, '300,301')
# Group name: (611, '301')
# Group name: (612, '301')
# Group name: (613, '301')
# Group name: (614, '301')
# Group name: (615, '301')
# Group name: (616, '301,302')
# Group name: (617, '301,302,303')
# Group name: (618, '302,303')
# Group name: (619, '303')
# Group name: (620, '303')
# Group name: (621, '303,304')
# Group name: (622, '303,304')
# Group name: (623, '304')
# Group name: (624, '304,305')
# Group name: (625, '304,305')
# Group name: (626, '305')
# Group name: (627, '305')
# Group name: (628, '305,306')
# Group name: (629, '305,306')
# Group name: (630, '306')
# Group name: (631, '306')
# Group name: (632, '306,307')
# Group name: (633, '306,307')
# Group name: (634, '307')
# Group name: (635, '307')
# Group name: (636, '307,308')
# Group name: (637, '307,308')
# Group name: (638, '308')
# Group name: (639, '308')
# Group name: (640, '308')
# Group name: (641, '308,309')
# Group name: (642, '308,309')
# Group name: (643, '309')
# Group name: (644, '309')
# Group name: (645, '309,310')
# Group name: (646, '309,310')
# Group name: (647, '310')
# Group name: (648, '310')
# Group name: (649, '310,311')
# Group name: (650, '310,311')
# Group name: (651, '311')
# Group name: (652, '311')
# Group name: (653, '311,312')
# Group name: (654, '311,312')
# Group name: (655, '312')
# Group name: (656, '312')
# Group name: (657, '312')
# Group name: (658, '312,313')
# Group name: (659, '312,313')
# Group name: (660, '313')
# Group name: (661, '313')
# Group name: (662, '313,314')
# Group name: (663, '313,314')
# Group name: (664, '314')
# Group name: (665, '314')
# Group name: (666, '314,315')
# Group name: (667, '314,315')
# Group name: (668, '315')
# Group name: (669, '315,316')
# Group name: (670, '315,316')
# Group name: (671, '316')
# Group name: (672, '316')
# Group name: (673, '316')
# Group name: (674, '316')
# Group name: (675, '316')
# Group name: (676, '316')
# Group name: (677, '316')
# Group name: (678, '316,317')
# Group name: (679, '316,317')
# Group name: (680, '317')
# Group name: (681, '317')
# Group name: (682, '317')
# Group name: (683, '317')
# Group name: (684, '317')
# Group name: (685, '317,318')
# Group name: (686, '317,318')
# Group name: (687, '318')
# Group name: (688, '318')
# Group name: (689, '318')
# Group name: (690, '318')
# Group name: (691, '318')
# Group name: (692, '318')
# Group name: (693, '318')
# Group name: (694, '318,319')
# Group name: (695, '318,319')
# Group name: (696, '319')
# Group name: (697, '319')
# Group name: (698, '319')
# Group name: (699, '319')
# Group name: (700, '319')
# Group name: (701, '319')
# Group name: (702, '319')
# Group name: (703, '319,320')
# Group name: (704, '319,320')
# Group name: (705, '320')
# Group name: (706, '320')
# Group name: (707, '320')
# Group name: (708, '320')
# Group name: (709, '320')
# Group name: (710, '320')
# Group name: (711, '320,321')
# Group name: (712, '321')
# Group name: (713, '321')
# Group name: (714, '321')
# Group name: (715, '321')
# Group name: (716, '321')
# Group name: (717, '321')
# Group name: (718, '321')
# Group name: (719, '321,322')
# Group name: (720, '321,322')
# Group name: (721, '322')
# Group name: (722, '322')
# Group name: (723, '322')
# Group name: (724, '322')
# Group name: (725, '322')
# Group name: (726, '322,323')
# Group name: (727, '322,323')
# Group name: (728, '323,324')
# Group name: (729, '323,324')
# Group name: (730, '324')
# Group name: (731, '324')
# Group name: (732, '324,325')
# Group name: (733, '324,325')
# Group name: (734, '325')
# Group name: (735, '325')
# Group name: (736, '325')
# Group name: (737, '325')
# Group name: (738, '325')
# Group name: (739, '325')
# Group name: (740, '325,326')
# Group name: (741, '325,326')
# Group name: (742, '326')
# Group name: (743, '326')
# Group name: (744, '326')
# Group name: (745, '326')
# Group name: (746, '326')
# Group name: (747, '326')
# Group name: (748, '326')
# Group name: (749, '326')
# Group name: (750, '326,327')
# Group name: (751, '326,327')
# Group name: (752, '327')
# Group name: (753, '327')
# Group name: (754, '327')
# Group name: (755, '327')
# Group name: (756, '327')
# Group name: (757, '327')
# Group name: (758, '327,328')
# Group name: (759, '327,328')
# Group name: (760, '328')
# Group name: (761, '328')
# Group name: (762, '328')
# Group name: (763, '328')
# Group name: (764, '328')
# Group name: (765, '328')
# Group name: (766, '328')
# Group name: (767, '328,329')
# Group name: (768, '328,329')
# Group name: (769, '329')
# Group name: (770, '329')
# Group name: (771, '329')
# Group name: (772, '329,330')
# Group name: (773, '329,330')
# Group name: (774, '330')
# Group name: (775, '330')
# Group name: (776, '330')
# Group name: (777, '330')
# Group name: (778, '330')
# Group name: (779, '330')
# Group name: (780, '330')
# Group name: (781, '330,331')
# Group name: (782, '330,331')
# Group name: (783, '331')
# Group name: (784, '331')
# Group name: (785, '331')
# Group name: (786, '331')
# Group name: (787, '331')
# Group name: (788, '331,332')
# Group name: (789, '331,332')
# Group name: (790, '332')
# Group name: (791, '332')
# Group name: (792, '332')
# Group name: (793, '332')
# Group name: (794, '332')
# Group name: (795, '332,333')
# Group name: (796, '332,333,334')
# Group name: (797, '334')
# Group name: (798, '334')
# Group name: (799, '334')
# Group name: (800, '334')
# Group name: (801, '334,335')
# Group name: (802, '334,335')
# Group name: (803, '335')
# Group name: (804, '335')
# Group name: (805, '335')
# Group name: (806, '335,336')
# Group name: (807, '335,336')
# Group name: (808, '336')
# Group name: (809, '336')
# Group name: (810, '336')
# Group name: (811, '336')
# Group name: (812, '336')
# Group name: (813, '336')
# Group name: (814, '336,337')
# Group name: (815, '336,337')
# Group name: (816, '337')
# Group name: (817, '337')
# Group name: (818, '337')
# Group name: (819, '337')
# Group name: (820, '337')
# Group name: (821, '337,338')
# Group name: (822, '337,338')
# Group name: (823, '338')
# Group name: (824, '338')
# Group name: (825, '338')
# Group name: (826, '338')
# Group name: (827, '338,339')
# Group name: (828, '338,339')
# Group name: (829, '339')
# Group name: (830, '339')
# Group name: (831, '339')
# Group name: (832, '339')
# Group name: (833, '339')
# Group name: (834, '339')
# Group name: (835, '339,340')
# Group name: (836, '340')
# Group name: (837, '340')
# Group name: (838, '340')
# Group name: (839, '340')
# Group name: (840, '340,341')
# Group name: (841, '340,341')
# Group name: (842, '341')
# Group name: (843, '341')
# Group name: (844, '341')
# Group name: (845, '341')
# Group name: (846, '341')
# Group name: (847, '341,342')
# Group name: (848, '341,342')
# Group name: (849, '342')
# Group name: (850, '342')
# Group name: (851, '342')
# Group name: (852, '342')
# Group name: (853, '342')
# Group name: (854, '342')
# Group name: (855, '342')
# Group name: (856, '342,343')
# Group name: (857, '342,343')
# Group name: (858, '343')
# Group name: (859, '343')
# Group name: (860, '343')
# Group name: (861, '343')
# Group name: (862, '343,344')
# Group name: (863, '343,344')
# Group name: (864, '344')
# Group name: (865, '344')
# Group name: (866, '344')
# Group name: (867, '344')
# Group name: (868, '344')
# Group name: (869, '344')
# Group name: (870, '344')
# Group name: (871, '344,345')
# Group name: (872, '344,345')
# Group name: (873, '345')
# Group name: (874, '345')
# Group name: (875, '345')
# Group name: (876, '345')
# Group name: (877, '345')
# Group name: (878, '345')
# Group name: (879, '345,346')
# Group name: (880, '345,346')
# Group name: (881, '346')
# Group name: (882, '346')
# Group name: (883, '346')
# Group name: (884, '346')
# Group name: (885, '346')
# Group name: (886, '346')
# Group name: (887, '346,347')
# Group name: (888, '346,347')
# Group name: (889, '347')
# Group name: (890, '347')
# Group name: (891, '347')
# Group name: (892, '347')
# Group name: (893, '347')
# Group name: (894, '347')
# Group name: (895, '347,348')
# Group name: (896, '347,348,349')
# Group name: (897, '348,349')
# Group name: (898, '349')
# Group name: (899, '349')
# Group name: (900, '349')
# Group name: (901, '349')
# Group name: (902, '349')
# Group name: (903, '349')
# Group name: (904, '349,350')
# Group name: (905, '349,350')
# Group name: (906, '350')
# Group name: (907, '350')
# Group name: (908, '350')
# Group name: (909, '350')
# Group name: (910, '350')
# Group name: (911, '350')
# Group name: (912, '350')
# Group name: (913, '350')
# Group name: (914, '350,351')
# Group name: (915, '350,351')
# Group name: (916, '351')
# Group name: (917, '351')
# Group name: (918, '351')
# Group name: (919, '351')
# Group name: (920, '351')
# Group name: (921, '351')
# Group name: (922, '351,352')
# Group name: (923, '351,352')
# Group name: (924, '352')
# Group name: (925, '352')
# Group name: (926, '352')
# Group name: (927, '352')
# Group name: (928, '352')
# Group name: (929, '352')
# Group name: (930, '352')
# Group name: (931, '352')
# Group name: (932, '352,353')
# Group name: (933, '352,353')
# Group name: (934, '353')
# Group name: (935, '353,354')
# Group name: (936, '353,354')
# Group name: (937, '354')
# Group name: (938, '354')
# Group name: (939, '354')
# Group name: (940, '354')
# Group name: (941, '354')
# Group name: (942, '354,355')
# Group name: (943, '354,355')
# Group name: (944, '355')
# Group name: (945, '355')
# Group name: (946, '355')
# Group name: (947, '355')
# Group name: (948, '355')
# Group name: (949, '355')
# Group name: (950, '355')
# Group name: (951, '355,356')
# Group name: (952, '355,356')
# Group name: (953, '356')
# Group name: (954, '356')
# Group name: (955, '356')
# Group name: (956, '356')
# Group name: (957, '356')
# Group name: (958, '356')
# Group name: (959, '356')
# Group name: (960, '356,357')
# Group name: (961, '356,357')
# Group name: (962, '357,358')
# Group name: (963, '357,358')
# Group name: (964, '358')
# Group name: (965, '358,359')
# Group name: (966, '358,359')
# Group name: (967, '359')
# Group name: (968, '359')
# Group name: (969, '359')
# Group name: (970, '359')
# Group name: (971, '359')
# Group name: (972, '359')
# Group name: (973, '359,360')
# Group name: (974, '359,360')
# Group name: (975, '360')
# Group name: (976, '360')
# Group name: (977, '360')
# Group name: (978, '360')
# Group name: (979, '360')
# Group name: (980, '360')
# Group name: (981, '360')
# Group name: (982, '360')
# Group name: (983, '360')
# Group name: (984, '360,361')
# Group name: (985, '360,361')
# Group name: (986, '361')
# Group name: (987, '361')
# Group name: (988, '361')
# Group name: (989, '361')
# Group name: (990, '361')
# Group name: (991, '361')
# Group name: (992, '361,362')
# Group name: (993, '361,362,363')
# Group name: (994, '363')
# Group name: (995, '363')
# Group name: (996, '363')
# Group name: (997, '363')
# Group name: (998, '363')
# Group name: (999, '363')
# Group name: (1000, '363')
# Group name: (1001, '363,364')
# Group name: (1002, '363,364')
# Group name: (1003, '364')
# Group name: (1004, '364')
# Group name: (1005, '364')
# Group name: (1006, '364')
# Group name: (1007, '364')
# Group name: (1008, '364')
# Group name: (1009, '364')
# Group name: (1010, '364,365')
# Group name: (1011, '364,365')
# Group name: (1012, '365')
# Group name: (1013, '365')
# Group name: (1014, '365')
# Group name: (1015, '365')
# Group name: (1016, '365')
# Group name: (1017, '365,366')
# Group name: (1018, '365,366')
# Group name: (1019, '366')
# Group name: (1020, '366')
# Group name: (1021, '366')
# Group name: (1022, '366')
# Group name: (1023, '366,367')
# Group name: (1024, '366,367')
# Group name: (1025, '367')
# Group name: (1026, '367')
# Group name: (1027, '367')
# Group name: (1028, '367')
# Group name: (1029, '367')
# Group name: (1030, '367')
# Group name: (1031, '367')
# Group name: (1032, '367,368')
# Group name: (1033, '367,368')
# Group name: (1034, '368')
# Group name: (1035, '368')
# Group name: (1036, '368')
# Group name: (1037, '368')
# Group name: (1038, '368')
# Group name: (1039, '368')
# Group name: (1040, '368,369')
# Group name: (1041, '368,369')
# Group name: (1042, '369')
# Group name: (1043, '369')
# Group name: (1044, '369')
# Group name: (1045, '369')
# Group name: (1046, '369')
# Group name: (1047, '369')
# Group name: (1048, '369')
# Group name: (1049, '369,370')
# Group name: (1050, '369,370')
# Group name: (1051, '370')
# Group name: (1052, '370')
# Group name: (1053, '370')
# Group name: (1054, '370')
# Group name: (1055, '370')
# Group name: (1056, '370')
# Group name: (1057, '370,371')
# Group name: (1058, '371')
# Group name: (1059, '371')
# Group name: (1060, '371')
# Group name: (1061, '371')
# Group name: (1062, '371')
# Group name: (1063, '371')
# Group name: (1064, '371,372')
# Group name: (1065, '371,372')
# Group name: (1066, '372')
# Group name: (1067, '372')
# Group name: (1068, '372')
# Group name: (1069, '372')
# Group name: (1070, '372')
# Group name: (1071, '372')
# Group name: (1072, '372,373')
# Group name: (1073, '372,373')
# Group name: (1074, '373')
# Group name: (1075, '373')
# Group name: (1076, '373')
# Group name: (1077, '373')
# Group name: (1078, '373')
# Group name: (1079, '373,374')
# Group name: (1080, '373,374')
# Group name: (1081, '374')
# Group name: (1082, '374')
# Group name: (1083, '374')
# Group name: (1084, '374')
# Group name: (1085, '374')
# Group name: (1086, '374')
# Group name: (1087, '374,375')
# Group name: (1088, '374,375')
# Group name: (1089, '375')
# Group name: (1090, '375')
# Group name: (1091, '375')
# Group name: (1092, '375')
# Group name: (1093, '375')
# Group name: (1094, '375,376')
# Group name: (1095, '375,376')
# Group name: (1096, '376')
# Group name: (1097, '376')
# Group name: (1098, '376')
# Group name: (1099, '376,377')
# Group name: (1100, '376,377,378')
# Group name: (1101, '377,378')
# Group name: (1102, '378')
# Group name: (1103, '378')
# Group name: (1104, '378')
# Group name: (1105, '378,379')
# Group name: (1106, '378,379')
# Group name: (1107, '379')
# Group name: (1108, '379')
# Group name: (1109, '379')
# Group name: (1110, '379')
# Group name: (1111, '379')
# Group name: (1112, '379')
# Group name: (1113, '379,380')
# Group name: (1114, '379,380')
# Group name: (1115, '380')
# Group name: (1116, '380')
# Group name: (1117, '380')
# Group name: (1118, '380')
# Group name: (1119, '380')
# Group name: (1120, '380,381')
# Group name: (1121, '380,381')
# Group name: (1122, '381')
# Group name: (1123, '381')
# Group name: (1124, '381')
# Group name: (1125, '381')
# Group name: (1126, '381')
# Group name: (1127, '381')
# Group name: (1128, '381')
# Group name: (1129, '381')
# Group name: (1130, '381,382')
# Group name: (1131, '381,382')
# Group name: (1132, '382')
# Group name: (1133, '382')
# Group name: (1134, '382')
# Group name: (1135, '382')
# Group name: (1136, '382')
# Group name: (1137, '382')
# Group name: (1138, '382')
# Group name: (1139, '382')
# Group name: (1140, '382')
# Group name: (1141, '382')
# Group name: (1142, '382')
# Group name: (1143, '382')
# Group name: (1144, '382,383')
# Group name: (1145, '382,383')
# Group name: (1146, '383')
# Group name: (1147, '383')
# Group name: (1148, '383')
# Group name: (1149, '383')
# Group name: (1150, '383')
# Group name: (1151, '383')
# Group name: (1152, '383')
# Group name: (1153, '383')
# Group name: (1154, '383')
# Group name: (1155, '383')
# Group name: (1156, '383')
# Group name: (1157, '383')
# Group name: (1158, '383')
# Group name: (1159, '383,384')
# Group name: (1160, '383,384')
# Group name: (1161, '384')
# Group name: (1162, '384')
# Group name: (1163, '384')
# Group name: (1164, '384')
# Group name: (1165, '384')
# Group name: (1166, '384')
# Group name: (1167, '384')
# Group name: (1168, '384')
# Group name: (1169, '384')
# Group name: (1170, '384')
# Group name: (1171, '384')
# Group name: (1172, '384')
# Group name: (1173, '384')
# Group name: (1174, '384,385')
# Group name: (1175, '384,385')
# Group name: (1176, '385')
# Group name: (1177, '385')
# Group name: (1178, '385')
# Group name: (1179, '385')
# Group name: (1180, '385')
# Group name: (1181, '385')
# Group name: (1182, '385')
# Group name: (1183, '385')
# Group name: (1184, '385')
# Group name: (1185, '385')
# Group name: (1186, '385')
# Group name: (1187, '385')
# Group name: (1188, '385')
# Group name: (1189, '385,386')
# Group name: (1190, '385,386')
# Group name: (1191, '386')
# Group name: (1192, '386')
# Group name: (1193, '386')
# Group name: (1194, '386')
# Group name: (1195, '386')
# Group name: (1196, '386')
# Group name: (1197, '386')
# Group name: (1198, '386')
# Group name: (1199, '386')
# Group name: (1200, '386')
# Group name: (1201, '386')
# Group name: (1202, '386')
# Group name: (1203, '386')
# Group name: (1204, '386,387')
# Group name: (1205, '386,387')
# Group name: (1206, '387')
# Group name: (1207, '387')
# Group name: (1208, '387')
# Group name: (1209, '387')
# Group name: (1210, '387')
# Group name: (1211, '387')
# Group name: (1212, '387')
# Group name: (1213, '387')
# Group name: (1214, '387')
# Group name: (1215, '387')
# Group name: (1216, '387')
# Group name: (1217, '387')
# Group name: (1218, '387')
# Group name: (1219, '387')
# Group name: (1220, '387')
# Group name: (1221, '387')
# Group name: (1222, '387')
# Group name: (1223, '387')
# Group name: (1224, '387,388')
# Group name: (1225, '387,388')
# Group name: (1226, '388')
# Group name: (1227, '388')
# Group name: (1228, '388')
# Group name: (1229, '388')
# Group name: (1230, '388')
# Group name: (1231, '388')
# Group name: (1232, '388')
# Group name: (1233, '388')
# Group name: (1234, '388')
# Group name: (1235, '388')
# Group name: (1236, '388')
# Group name: (1237, '388')
# Group name: (1238, '388')
# Group name: (1239, '388')
# Group name: (1240, '388')
# Group name: (1241, '388')
# Group name: (1242, '388')
# Group name: (1243, '388')
# Group name: (1244, '388')
# Group name: (1245, '388,389')
# Group name: (1246, '388,389')
# Group name: (1247, '389')
# Group name: (1248, '389')
# Group name: (1249, '389')
# Group name: (1250, '389')
# Group name: (1251, '389')
# Group name: (1252, '389')
# Group name: (1253, '389')
# Group name: (1254, '389')
# Group name: (1255, '389')
# Group name: (1256, '389')
# Group name: (1257, '389')
# Group name: (1258, '389')
# Group name: (1259, '389')
# Group name: (1260, '389')
# Group name: (1261, '389')
# Group name: (1262, '389,390')
# Group name: (1263, '389,390')
# Group name: (1264, '390')
# Group name: (1265, '390')
# Group name: (1266, '390')
# Group name: (1267, '390')
# Group name: (1268, '390')
# Group name: (1269, '390')
# Group name: (1270, '390')
# Group name: (1271, '390')
# Group name: (1272, '390')
# Group name: (1273, '390')
# Group name: (1274, '390')
# Group name: (1275, '390')
# Group name: (1276, '390')
# Group name: (1277, '390')
# Group name: (1278, '390')
# Group name: (1279, '390')
# Group name: (1280, '390')
# Group name: (1281, '390,391')
# Group name: (1282, '390,391')
# Group name: (1283, '391')
# Group name: (1284, '391')
# Group name: (1285, '391')
# Group name: (1286, '391')
# Group name: (1287, '391')
# Group name: (1288, '391')
# Group name: (1289, '391')
# Group name: (1290, '391')
# Group name: (1291, '391')
# Group name: (1292, '391')
# Group name: (1293, '391')
# Group name: (1294, '391')
# Group name: (1295, '391')
# Group name: (1296, '391')
# Group name: (1297, '391')
# Group name: (1298, '391,392')
# Group name: (1299, '391,392')
# Group name: (1300, '392')
# Group name: (1301, '392')
# Group name: (1302, '392')
# Group name: (1303, '392')
# Group name: (1304, '392')
# Group name: (1305, '392')
# Group name: (1306, '392')
# Group name: (1307, '392')
# Group name: (1308, '392')
# Group name: (1309, '392')
# Group name: (1310, '392')
# Group name: (1311, '392')
# Group name: (1312, '392')
# Group name: (1313, '392')
# Group name: (1314, '392')
# Group name: (1315, '392')
# Group name: (1316, '392,393')
# Group name: (1317, '392,393')
# Group name: (1318, '393')
# Group name: (1319, '393')
# Group name: (1320, '393')
# Group name: (1321, '393')
# Group name: (1322, '393')
# Group name: (1323, '393')
# Group name: (1324, '393')
# Group name: (1325, '393')
# Group name: (1326, '393')
# Group name: (1327, '393')
# Group name: (1328, '393')
# Group name: (1329, '393')
# Group name: (1330, '393')
# Group name: (1331, '393')
# Group name: (1332, '393')
# Group name: (1333, '393')
# Group name: (1334, '393')
# Group name: (1335, '393')
# Group name: (1336, '393')
# Group name: (1337, '393')
# Group name: (1338, '393')
# Group name: (1339, '393,394')
# Group name: (1340, '393,394')
# Group name: (1341, '394')
# Group name: (1342, '394')
# Group name: (1343, '394')
# Group name: (1344, '394')
# Group name: (1345, '394')
# Group name: (1346, '394')
# Group name: (1347, '394')
# Group name: (1348, '394')
# Group name: (1349, '394')
# Group name: (1350, '394')
# Group name: (1351, '394')
# Group name: (1352, '394')
# Group name: (1353, '394')
# Group name: (1354, '394')
# Group name: (1355, '394')
# Group name: (1356, '394,395')
# Group name: (1357, '394,395')
# Group name: (1358, '395')
# Group name: (1359, '395')
# Group name: (1360, '395')
# Group name: (1361, '395')
# Group name: (1362, '395')
# Group name: (1363, '395')
# Group name: (1364, '395')
# Group name: (1365, '395')
# Group name: (1366, '395')
# Group name: (1367, '395')
# Group name: (1368, '395')
# Group name: (1369, '395')
# Group name: (1370, '395')
# Group name: (1371, '395,396')
# Group name: (1372, '395,396')
# Group name: (1373, '396')
# Group name: (1374, '396')
# Group name: (1375, '396')
# Group name: (1376, '396')
# Group name: (1377, '396')
# Group name: (1378, '396')
# Group name: (1379, '396')
# Group name: (1380, '396')
# Group name: (1381, '396')
# Group name: (1382, '396')
# Group name: (1383, '396')
# Group name: (1384, '396')
# Group name: (1385, '396')
# Group name: (1386, '396')
# Group name: (1387, '396')
# Group name: (1388, '396,397')
# Group name: (1389, '396,397')
# Group name: (1390, '397')
# Group name: (1391, '397')
# Group name: (1392, '397')
# Group name: (1393, '397')
# Group name: (1394, '397')
# Group name: (1395, '397')
# Group name: (1396, '397')
# Group name: (1397, '397')
# Group name: (1398, '397')
# Group name: (1399, '397')
# Group name: (1400, '397')
# Group name: (1401, '397')
# Group name: (1402, '397')
# Group name: (1403, '397')
# Group name: (1404, '397')
# Group name: (1405, '397,398')
# Group name: (1406, '397,398')
# Group name: (1407, '398')
# Group name: (1408, '398')
# Group name: (1409, '398')
# Group name: (1410, '398')
# Group name: (1411, '398')
# Group name: (1412, '398')
# Group name: (1413, '398')
# Group name: (1414, '398')
# Group name: (1415, '398')
# Group name: (1416, '398')
# Group name: (1417, '398,399')
# Group name: (1418, '398,399')
# Group name: (1419, '399')
# Group name: (1420, '399')
# Group name: (1421, '399')
# Group name: (1422, '399')
# Group name: (1423, '399')
# Group name: (1424, '399')
# Group name: (1425, '399')
# Group name: (1426, '399')
# Group name: (1427, '399')
# Group name: (1428, '399')
# Group name: (1429, '399')
# Group name: (1430, '399')
# Group name: (1431, '399')
# Group name: (1432, '399')
# Group name: (1433, '399')
# Group name: (1434, '399')
# Group name: (1435, '399')
# Group name: (1436, '399')
# Group name: (1437, '399')
# Group name: (1438, '399')
# Group name: (1439, '399')
# Group name: (1440, '399')
# Group name: (1441, '399,400')
# Group name: (1442, '399,400')
# Group name: (1443, '400')
# Group name: (1444, '400')
# Group name: (1445, '400')
# Group name: (1446, '400')
# Group name: (1447, '400')
# Group name: (1448, '400')
# Group name: (1449, '400')
# Group name: (1450, '400')
# Group name: (1451, '400')
# Group name: (1452, '400')
# Group name: (1453, '400')
# Group name: (1454, '400')
# Group name: (1455, '400')
# Group name: (1456, '400')
# Group name: (1457, '400')
# Group name: (1458, '400')
# Group name: (1459, '400,401')
# Group name: (1460, '400,401')
# Group name: (1461, '401')
# Group name: (1462, '401')
# Group name: (1463, '401')
# Group name: (1464, '401')
# Group name: (1465, '401')
# Group name: (1466, '401')
# Group name: (1467, '401')
# Group name: (1468, '401')
# Group name: (1469, '401')
# Group name: (1470, '401')
# Group name: (1471, '401')
# Group name: (1472, '401')
# Group name: (1473, '401')
# Group name: (1474, '401')
# Group name: (1475, '401')
# Group name: (1476, '401')
# Group name: (1477, '401,402')
# Group name: (1478, '401,402')
# Group name: (1479, '402')
# Group name: (1480, '402')
# Group name: (1481, '402')
# Group name: (1482, '402')
# Group name: (1483, '402')
# Group name: (1484, '402')
# Group name: (1485, '402')
# Group name: (1486, '402')
# Group name: (1487, '402')
# Group name: (1488, '402')
# Group name: (1489, '402')
# Group name: (1490, '402')
# Group name: (1491, '402')
# Group name: (1492, '402')
# Group name: (1493, '402,403')
# Group name: (1494, '402,403')
# Group name: (1495, '403')
# Group name: (1496, '403')
# Group name: (1497, '403')
# Group name: (1498, '403')
# Group name: (1499, '403')
# Group name: (1500, '403')
# Group name: (1501, '403')
# Group name: (1502, '403')
# Group name: (1503, '403')
# Group name: (1504, '403')
# Group name: (1505, '403')
# Group name: (1506, '403')
# Group name: (1507, '403')
# Group name: (1508, '403')
# Group name: (1509, '403')
# Group name: (1510, '403,404')
# Group name: (1511, '403,404')
# Group name: (1512, '404')
# Group name: (1513, '404')
# Group name: (1514, '404')
# Group name: (1515, '404')
# Group name: (1516, '404')
# Group name: (1517, '404')
# Group name: (1518, '404')
# Group name: (1519, '404')
# Group name: (1520, '404')
# Group name: (1521, '404')
# Group name: (1522, '404')
# Group name: (1523, '404')
# Group name: (1524, '404')
# Group name: (1525, '404')
# Group name: (1526, '404')
# Group name: (1527, '404')
# Group name: (1528, '404,405')
# Group name: (1529, '404,405')
# Group name: (1530, '405')
# Group name: (1531, '405')
# Group name: (1532, '405')
# Group name: (1533, '405')
# Group name: (1534, '405')
# Group name: (1535, '405')
# Group name: (1536, '405')
# Group name: (1537, '405')
# Group name: (1538, '405')
# Group name: (1539, '405')
# Group name: (1540, '405')
# Group name: (1541, '405')
# Group name: (1542, '405')
# Group name: (1543, '405')
# Group name: (1544, '405')
# Group name: (1545, '405')
# Group name: (1546, '405')
# Group name: (1547, '405,406')
# Group name: (1548, '405,406')
# Group name: (1549, '406')
# Group name: (1550, '406')
# Group name: (1551, '406')
# Group name: (1552, '406')
# Group name: (1553, '406')
# Group name: (1554, '406')
# Group name: (1555, '406')
# Group name: (1556, '406')
# Group name: (1557, '406')
# Group name: (1558, '406')
# Group name: (1559, '406')
# Group name: (1560, '406')
# Group name: (1561, '406')
# Group name: (1562, '406')
# Group name: (1563, '406')
# Group name: (1564, '406')
# Group name: (1565, '406')
# Group name: (1566, '406')
# Group name: (1567, '406,407')
# Group name: (1568, '406,407')
# Group name: (1569, '407')
# Group name: (1570, '407')
# Group name: (1571, '407')
# Group name: (1572, '407')
# Group name: (1573, '407')
# Group name: (1574, '407')
# Group name: (1575, '407')
# Group name: (1576, '407')
# Group name: (1577, '407')
# Group name: (1578, '407')
# Group name: (1579, '407')
# Group name: (1580, '407')
# Group name: (1581, '407')
# Group name: (1582, '407')
# Group name: (1583, '407')
# Group name: (1584, '407')
# Group name: (1585, '407')
# Group name: (1586, '407')
# Group name: (1587, '407')
# Group name: (1588, '407,408')
# Group name: (1589, '407,408')
# Group name: (1590, '408')
# Group name: (1591, '408')
# Group name: (1592, '408')
# Group name: (1593, '408')
# Group name: (1594, '408')
# Group name: (1595, '408')
# Group name: (1596, '408')
# Group name: (1597, '408')
# Group name: (1598, '408')
# Group name: (1599, '408')
# Group name: (1600, '408')
# Group name: (1601, '408')
# Group name: (1602, '408')
# Group name: (1603, '408')
# Group name: (1604, '408')
# Group name: (1605, '408')
# Group name: (1606, '408,409')
# Group name: (1607, '408,409')
# Group name: (1608, '409')
# Group name: (1609, '409')
# Group name: (1610, '409')
# Group name: (1611, '409')
# Group name: (1612, '409')
# Group name: (1613, '409')
# Group name: (1614, '409')
# Group name: (1615, '409')
# Group name: (1616, '409')
# Group name: (1617, '409')
# Group name: (1618, '409')
# Group name: (1619, '409')
# Group name: (1620, '409')
# Group name: (1621, '409')
# Group name: (1622, '409')
# Group name: (1623, '409')
# Group name: (1624, '409')
# Group name: (1625, '409')
# Group name: (1626, '409,410')
# Group name: (1627, '409,410')
# Group name: (1628, '410')
# Group name: (1629, '410')
# Group name: (1630, '410')
# Group name: (1631, '410')
# Group name: (1632, '410')
# Group name: (1633, '410')
# Group name: (1634, '410')
# Group name: (1635, '410')
# Group name: (1636, '410')
# Group name: (1637, '410')
# Group name: (1638, '410')
# Group name: (1639, '410')
# Group name: (1640, '410')
# Group name: (1641, '410')
# Group name: (1642, '410')
# Group name: (1643, '0')
# Group name: (1644, '0,1')
# Group name: (1645, '0,1')
# Group name: (1646, '1,2')
# Group name: (1647, '1,2')
# Group name: (1648, '2')
# Group name: (1649, '2,3')
# Group name: (1650, '2,3')
# Group name: (1651, '3')
# Group name: (1652, '3,4')
# Group name: (1653, '3,4')
# Group name: (1654, '4')
# Group name: (1655, '4,5')
# Group name: (1656, '4,5')
# Group name: (1657, '5')
# Group name: (1658, '5,6')
# Group name: (1659, '5,6')
# Group name: (1660, '6,7')
# Group name: (1661, '6,7')
# Group name: (1662, '7')
# Group name: (1663, '7,8')
# Group name: (1664, '7,8')
# Group name: (1665, '8,9')
# Group name: (1666, '8,9')
# Group name: (1667, '9')
# Group name: (1668, '9,10')
# Group name: (1669, '9,10')
# Group name: (1670, '10,11')
# Group name: (1671, '10,11')
# Group name: (1672, '11,12')
# Group name: (1673, '11,12')
# Group name: (1674, '12')
# Group name: (1675, '12,13')
# Group name: (1676, '12,13')
# Group name: (1677, '13')
# Group name: (1678, '13,14')
# Group name: (1679, '13,14')
# Group name: (1680, '14')
# Group name: (1681, '14,15')
# Group name: (1682, '15')
# Group name: (1683, '15,16')
# Group name: (1684, '15,16')
# Group name: (1685, '16')
# Group name: (1686, '16,17')
# Group name: (1687, '16,17')
# Group name: (1688, '17')
# Group name: (1689, '17,18')
# Group name: (1690, '17,18')
# Group name: (1691, '18')
# Group name: (1692, '18,19')
# Group name: (1693, '18,19')
# Group name: (1694, '19')
# Group name: (1695, '19,20')
# Group name: (1696, '19,20')
# Group name: (1697, '20')
# Group name: (1698, '20,21')
# Group name: (1699, '21')
# Group name: (1700, '21,22')
# Group name: (1701, '21,22')
# Group name: (1702, '22')
# Group name: (1703, '22,23')
# Group name: (1704, '22,23')
# Group name: (1705, '23')
# Group name: (1706, '23,24')
# Group name: (1707, '23,24')
# Group name: (1708, '24')
# Group name: (1709, '24,25')
# Group name: (1710, '24,25')
# Group name: (1711, '25')
# Group name: (1712, '25,26')
# Group name: (1713, '25,26')
# Group name: (1714, '26,27')
# Group name: (1715, '26,27')
# Group name: (1716, '27')
# Group name: (1717, '27,28')
# Group name: (1718, '27,28')
# Group name: (1719, '28')
# Group name: (1720, '28,29')
# Group name: (1721, '28,29')
# Group name: (1722, '29')
# Group name: (1723, '29,30')
# Group name: (1724, '29,30')
# Group name: (1725, '30')
# Group name: (1726, '30,31')
# Group name: (1727, '30,31')
# Group name: (1728, '31')
# Group name: (1729, '31,32')
# Group name: (1730, '31,32')
# Group name: (1731, '32')
# Group name: (1732, '32,33')
# Group name: (1733, '32,33')
# Group name: (1734, '33')
# Group name: (1735, '33,34')
# Group name: (1736, '33,34')
# Group name: (1737, '34')
# Group name: (1738, '34,35')
# Group name: (1739, '34,35')
# Group name: (1740, '35')
# Group name: (1741, '35,36')
# Group name: (1742, '35,36')
# Group name: (1743, '36')
# Group name: (1744, '36,37')
# Group name: (1745, '36,37')
# Group name: (1746, '37')
# Group name: (1747, '37,38')
# Group name: (1748, '37,38')
# Group name: (1749, '38')
# Group name: (1750, '38,39')
# Group name: (1751, '38,39')
# Group name: (1752, '39')
# Group name: (1753, '39,40')
# Group name: (1754, '39,40')
# Group name: (1755, '40')
# Group name: (1756, '40,41')
# Group name: (1757, '41')
# Group name: (1758, '41')
# Group name: (1759, '41,42')
# Group name: (1760, '41,42')
# Group name: (1761, '42')
# Group name: (1762, '42,43')
# Group name: (1763, '42,43')
# Group name: (1764, '43')
# Group name: (1765, '43,44')
# Group name: (1766, '43,44')
# Group name: (1767, '44')
# Group name: (1768, '44,45')
# Group name: (1769, '44,45')
# Group name: (1770, '45')
# Group name: (1771, '45,46')
# Group name: (1772, '45,46')
# Group name: (1773, '46')
# Group name: (1774, '46,47')
# Group name: (1775, '46,47')
# Group name: (1776, '47')
# Group name: (1777, '47,48')
# Group name: (1778, '47,48')
# Group name: (1779, '48')
# ...
# Group name: (13407, '410')
# Group name: (13408, '410')
# Group name: (13409, '410')
# Group name: (13410, '410')
# Group name: (13411, '410')
# Group name: (13412, '410')
# Group name: (13413, '410')
# Group name: (13414, '410')
# Group name: (13415, '410')
# Group name: (13416, '410')
# Group name: (13417, '410')
# Group name: (13418, '410')
# Group name: (13419, '410')
# Group name: (13420, '410')
# Group name: (13421, '410')
# Group name: (13422, '410')
# Group name: (13423, '410')
# Group name: (13424, '410')
# Group name: (13425, '410')
# Group name: (13426, '410,411')
# Group name: (13427, '410,411')
# Group name: (13428, '411')
# Group name: (13429, '411')
# Group name: (13430, '411')
# Group name: (13431, '411')
# Group name: (13432, '411')
# Group name: (13433, '411')
# Group name: (13434, '411')
# Group name: (13435, '411')
# Group name: (13436, '411')
# Group name: (13437, '411')
# Group name: (13438, '411')
# Group name: (13439, '411')
# Group name: (13440, '411')
# Group name: (13441, '411')
# Group name: (13442, '411')
# Group name: (13443, '411')
# Group name: (13444, '411')
# Group name: (13445, '411')
# Group name: (13446, '411')
# Group name: (13447, '411')
# Group name: (13448, '411')
# Group name: (13449, '411')
# Group name: (13450, '411')
# Group name: (13451, '411,412')
# Group name: (13452, '411,412')
# Group name: (13453, '412')
# Group name: (13454, '412')
# Group name: (13455, '412')
# Group name: (13456, '412')
# Group name: (13457, '412')
# Group name: (13458, '412')
# Group name: (13459, '412')
# Group name: (13460, '412')
# Group name: (13461, '412')
# Group name: (13462, '412')
# Group name: (13463, '412')
# Group name: (13464, '412')
# Group name: (13465, '412')
# Group name: (13466, '412')
# Group name: (13467, '412')
# Group name: (13468, '412')
# Group name: (13469, '412')
# Group name: (13470, '412')
# Group name: (13471, '412')
# Group name: (13472, '412,413')
# Group name: (13473, '412,413')
# Group name: (13474, '413')
# Group name: (13475, '413')
# Group name: (13476, '413')
# Group name: (13477, '413')
# Group name: (13478, '413')
# Group name: (13479, '413')
# Group name: (13480, '413')
# Group name: (13481, '413')
# Group name: (13482, '413')
# Group name: (13483, '413')
# Group name: (13484, '413')
# Group name: (13485, '413')
# Group name: (13486, '413')
# Group name: (13487, '413,414')
# Group name: (13488, '413,414')
# Group name: (13489, '414')
# Group name: (13490, '414')
# Group name: (13491, '414')
# Group name: (13492, '414')
# Group name: (13493, '414')
# Group name: (13494, '414')
# Group name: (13495, '414')
# Group name: (13496, '414')
# Group name: (13497, '414')
# Group name: (13498, '414')
# Group name: (13499, '414')
# Group name: (13500, '414')
# Group name: (13501, '414')
# Group name: (13502, '414')
# Group name: (13503, '414')
# Group name: (13504, '414,415')
# Group name: (13505, '414,415')
# Group name: (13506, '415')
# Group name: (13507, '415')
# Group name: (13508, '415')
# Group name: (13509, '415')
# Group name: (13510, '415')
# Group name: (13511, '415')
# Group name: (13512, '415')
# Group name: (13513, '415')
# Group name: (13514, '415')
# Group name: (13515, '415')
# Group name: (13516, '415')
# Group name: (13517, '415')
# Group name: (13518, '415')
# Group name: (13519, '415,416')
# Group name: (13520, '415,416')
# Group name: (13521, '416')
# Group name: (13522, '416')
# Group name: (13523, '416')
# Group name: (13524, '416')
# Group name: (13525, '416')
# Group name: (13526, '416')
# Group name: (13527, '416')
# Group name: (13528, '416')
# Group name: (13529, '416')
# Group name: (13530, '416')
# Group name: (13531, '416')
# Group name: (13532, '416')
# Group name: (13533, '416')
# Group name: (13534, '416')
# Group name: (13535, '416')
# Group name: (13536, '416')
# Group name: (13537, '416,417')
# Group name: (13538, '416,417')
# Group name: (13539, '417')
# Group name: (13540, '417')
# Group name: (13541, '417')
# Group name: (13542, '417')
# Group name: (13543, '417')
# Group name: (13544, '417')
# Group name: (13545, '417')
# Group name: (13546, '417')
# Group name: (13547, '417')
# Group name: (13548, '417')
# Group name: (13549, '417')
# Group name: (13550, '417')
# Group name: (13551, '417')
# Group name: (13552, '417,418')
# Group name: (13553, '417,418')
# Group name: (13554, '418')
# Group name: (13555, '418')
# Group name: (13556, '418')
# Group name: (13557, '418')
# Group name: (13558, '418')
# Group name: (13559, '418')
# Group name: (13560, '418')
# Group name: (13561, '418')
# Group name: (13562, '418')
# Group name: (13563, '418')
# Group name: (13564, '418')
# Group name: (13565, '418')
# Group name: (13566, '418')
# Group name: (13567, '418,419')
# Group name: (13568, '419')
# Group name: (13569, '419')
# Group name: (13570, '419')
# Group name: (13571, '419')
# Group name: (13572, '419')
# Group name: (13573, '419')
# Group name: (13574, '419')
# Group name: (13575, '419')
# Group name: (13576, '419')
# Group name: (13577, '419')
# Group name: (13578, '419')
# Group name: (13579, '419')
# Group name: (13580, '419')
# Group name: (13581, '419,420')
# Group name: (13582, '420')
# Group name: (13583, '420')
# Group name: (13584, '420')
# Group name: (13585, '420')
# Group name: (13586, '420')
# Group name: (13587, '420')
# Group name: (13588, '420')
# Group name: (13589, '420')
# Group name: (13590, '420')
# Group name: (13591, '420')
# Group name: (13592, '420')
# Group name: (13593, '420')
# Group name: (13594, '420')
# Group name: (13595, '420,421')
# Group name: (13596, '420,421')
# Group name: (13597, '421')
# Group name: (13598, '421')
# Group name: (13599, '421')
# Group name: (13600, '421')
# Group name: (13601, '421')
# Group name: (13602, '421')
# Group name: (13603, '421')
# Group name: (13604, '421')
# Group name: (13605, '421')
# Group name: (13606, '421')
# Group name: (13607, '421')
# Group name: (13608, '421')
# Group name: (13609, '421')
# Group name: (13610, '421')
# Group name: (13611, '421,422,423')
# Group name: (13612, '421,422,423')
# Group name: (13613, '423')
# Group name: (13614, '423')
# Group name: (13615, '423')
# Group name: (13616, '423')
# Group name: (13617, '423')
# Group name: (13618, '423')
# Group name: (13619, '423')
# Group name: (13620, '423')
# Group name: (13621, '423')
# Group name: (13622, '423')
# Group name: (13623, '423')
# Group name: (13624, '423')
# Group name: (13625, '423')
# Group name: (13626, '423')
# Group name: (13627, '423,424')
# Group name: (13628, '423,424')
# Group name: (13629, '424')
# Group name: (13630, '424')
# Group name: (13631, '424')
# Group name: (13632, '424')
# Group name: (13633, '424')
# Group name: (13634, '424')
# Group name: (13635, '424')
# Group name: (13636, '424')
# Group name: (13637, '424')
# Group name: (13638, '424')
# Group name: (13639, '424')
# Group name: (13640, '424')
# Group name: (13641, '424')
# Group name: (13642, '424')
# Group name: (13643, '424,425')
# Group name: (13644, '424,425')
# Group name: (13645, '425')
# Group name: (13646, '425')
# Group name: (13647, '425')
# Group name: (13648, '425')
# Group name: (13649, '425')
# Group name: (13650, '425')
# Group name: (13651, '425')
# Group name: (13652, '425')
# Group name: (13653, '425')
# Group name: (13654, '425')
# Group name: (13655, '425')
# Group name: (13656, '425')
# Group name: (13657, '425')
# Group name: (13658, '425')
# Group name: (13659, '425')
# Group name: (13660, '425,426')
# Group name: (13661, '425,426')
# Group name: (13662, '426')
# Group name: (13663, '426')
# Group name: (13664, '426')
# Group name: (13665, '426')
# Group name: (13666, '426')
# Group name: (13667, '426')
# Group name: (13668, '426')
# Group name: (13669, '426')
# Group name: (13670, '426')
# Group name: (13671, '426')
# Group name: (13672, '426')
# Group name: (13673, '426')
# Group name: (13674, '426')
# Group name: (13675, '426')
# Group name: (13676, '426,427')
# Group name: (13677, '426,427')
# Group name: (13678, '427')
# Group name: (13679, '427')
# Group name: (13680, '427')
# Group name: (13681, '427')
# Group name: (13682, '427')
# Group name: (13683, '427')
# Group name: (13684, '427')
# Group name: (13685, '427')
# Group name: (13686, '427')
# Group name: (13687, '427')
# Group name: (13688, '427')
# Group name: (13689, '427')
# Group name: (13690, '427')
# Group name: (13691, '427')
# Group name: (13692, '427')
# Group name: (13693, '427,428')
# Group name: (13694, '427,428')
# Group name: (13695, '428')
# Group name: (13696, '428')
# Group name: (13697, '428')
# Group name: (13698, '428')
# Group name: (13699, '428')
# Group name: (13700, '428')
# Group name: (13701, '428')
# Group name: (13702, '428')
# Group name: (13703, '428')
# Group name: (13704, '428')
# Group name: (13705, '428')
# Group name: (13706, '428')
# Group name: (13707, '428,429')
# Group name: (13708, '428,429')
# Group name: (13709, '429')
# Group name: (13710, '429')
# Group name: (13711, '429')
# Group name: (13712, '429')
# Group name: (13713, '429')
# Group name: (13714, '429')
# Group name: (13715, '429')
# Group name: (13716, '429')
# Group name: (13717, '429')
# Group name: (13718, '429')
# Group name: (13719, '429')
# Group name: (13720, '429')
# Group name: (13721, '429')
# Group name: (13722, '429,430')
# Group name: (13723, '429,430')
# Group name: (13724, '430')
# Group name: (13725, '430')
# Group name: (13726, '430')
# Group name: (13727, '430')
# Group name: (13728, '430')
# Group name: (13729, '430')
# Group name: (13730, '430')
# Group name: (13731, '430')
# Group name: (13732, '430')
# Group name: (13733, '430')
# Group name: (13734, '430')
# Group name: (13735, '430')
# Group name: (13736, '430')
# Group name: (13737, '430,431,432')
# Group name: (13738, '430,431,432')
# Group name: (13739, '432')
# Group name: (13740, '432')
# Group name: (13741, '432')
# Group name: (13742, '432')
# Group name: (13743, '432')
# Group name: (13744, '432')
# Group name: (13745, '432')
# Group name: (13746, '432')
# Group name: (13747, '432')
# Group name: (13748, '432')
# Group name: (13749, '432')
# Group name: (13750, '432')
# Group name: (13751, '432')
# Group name: (13752, '432')
# Group name: (13753, '432,433')
# Group name: (13754, '432,433')
# Group name: (13755, '433')
# Group name: (13756, '433')
# Group name: (13757, '433')
# Group name: (13758, '433')
# Group name: (13759, '433')
# Group name: (13760, '433')
# Group name: (13761, '433')
# Group name: (13762, '433')
# Group name: (13763, '433')
# Group name: (13764, '433')
# Group name: (13765, '433')
# Group name: (13766, '433')
# Group name: (13767, '433,434')
# Group name: (13768, '433,434')
# Group name: (13769, '434')
# Group name: (13770, '434')
# Group name: (13771, '434')
# Group name: (13772, '434')
# Group name: (13773, '434')
# Group name: (13774, '434')
# Group name: (13775, '434')
# Group name: (13776, '434')
# Group name: (13777, '434')
# Group name: (13778, '434')
# Group name: (13779, '434')
# Group name: (13780, '434')
# Group name: (13781, '434')
# Group name: (13782, '434,435,436')
# Group name: (13783, '434,435,436')
# Group name: (13784, '436')
# Group name: (13785, '436')
# Group name: (13786, '436')
# Group name: (13787, '436')
# Group name: (13788, '436')
# Group name: (13789, '436')
# Group name: (13790, '436')
# Group name: (13791, '436')
# Group name: (13792, '436')
# Group name: (13793, '436')
# Group name: (13794, '436')
# Group name: (13795, '436')
# Group name: (13796, '436')
# Group name: (13797, '436,437')
# Group name: (13798, '436,437')
# Group name: (13799, '437')
# Group name: (13800, '437')
# Group name: (13801, '437')
# Group name: (13802, '437')
# Group name: (13803, '437')
# Group name: (13804, '437')
# Group name: (13805, '437')
# Group name: (13806, '437')
# Group name: (13807, '437')
# Group name: (13808, '437')
# Group name: (13809, '437')
# Group name: (13810, '437')
# Group name: (13811, '437')
# Group name: (13812, '437,438')
# Group name: (13813, '437,438')
# Group name: (13814, '438')
# Group name: (13815, '438')
# Group name: (13816, '438')
# Group name: (13817, '438')
# Group name: (13818, '438')
# Group name: (13819, '438')
# Group name: (13820, '438')
# Group name: (13821, '438')
# Group name: (13822, '438')
# Group name: (13823, '438')
# Group name: (13824, '438')
# Group name: (13825, '438')
# Group name: (13826, '438')
# Group name: (13827, '438,439')
# Group name: (13828, '438,439')
# Group name: (13829, '439')
# Group name: (13830, '439')
# Group name: (13831, '439')
# Group name: (13832, '439')
# Group name: (13833, '439')
# Group name: (13834, '439')
# Group name: (13835, '439')
# Group name: (13836, '439')
# Group name: (13837, '439')
# Group name: (13838, '439')
# Group name: (13839, '439')
# Group name: (13840, '439')
# Group name: (13841, '439,440')
# Group name: (13842, '439,440')
# Group name: (13843, '440')
# Group name: (13844, '440')
# Group name: (13845, '440')
# Group name: (13846, '440')
# Group name: (13847, '440')
# Group name: (13848, '440')
# Group name: (13849, '440')
# Group name: (13850, '440')
# Group name: (13851, '440')
# Group name: (13852, '440')
# Group name: (13853, '440')
# Group name: (13854, '440')
# Group name: (13855, '440')
# Group name: (13856, '440')
# Group name: (13857, '440,441')
# Group name: (13858, '440,441')
# Group name: (13859, '441')
# Group name: (13860, '441')
# Group name: (13861, '441')
# Group name: (13862, '441')
# Group name: (13863, '441')
# Group name: (13864, '441')
# Group name: (13865, '441')
# Group name: (13866, '441')
# Group name: (13867, '441')
# Group name: (13868, '441')
# Group name: (13869, '441')
# Group name: (13870, '441')
# Group name: (13871, '441')
# Group name: (13872, '441')
# Group name: (13873, '441,442')
# Group name: (13874, '441,442')
# Group name: (13875, '442')
# Group name: (13876, '442')
# Group name: (13877, '442')
# Group name: (13878, '442')
# Group name: (13879, '442')
# Group name: (13880, '442')
# Group name: (13881, '442')
# Group name: (13882, '442')
# Group name: (13883, '442')
# Group name: (13884, '442')
# Group name: (13885, '442')
# Group name: (13886, '442,443')
# Group name: (13887, '442,443')
# Group name: (13888, '443')
# Group name: (13889, '443')
# Group name: (13890, '443')
# Group name: (13891, '443')
# Group name: (13892, '443')
# Group name: (13893, '443')
# Group name: (13894, '443')
# Group name: (13895, '443')
# Group name: (13896, '443')
# Group name: (13897, '443')
# Group name: (13898, '443')
# Group name: (13899, '443')
# Group name: (13900, '443')
# Group name: (13901, '443,444')
# Group name: (13902, '444')
# Group name: (13903, '444')
# Group name: (13904, '444')
# Group name: (13905, '444')
# Group name: (13906, '444')
# Group name: (13907, '444')
# Group name: (13908, '444')
# Group name: (13909, '444')
# Group name: (13910, '444')
# Group name: (13911, '444')
# Group name: (13912, '444,445')
# Group name: (13913, '444,445')
# Group name: (13914, '445')
# Group name: (13915, '445')
# Group name: (13916, '445')
# Group name: (13917, '445')
# Group name: (13918, '445')
# Group name: (13919, '445')
# Group name: (13920, '445')
# Group name: (13921, '445,446')
# Group name: (13922, '445,446')
# Group name: (13923, '446')
# Group name: (13924, '446')
# Group name: (13925, '446')
# Group name: (13926, '446')
# Group name: (13927, '446')
# Group name: (13928, '446,447')
# Group name: (13929, '446,447')
# Group name: (13930, '447')
# Group name: (13931, '447')
# Group name: (13932, '447')
# Group name: (13933, '447')
# Group name: (13934, '447')
# Group name: (13935, '447')
# Group name: (13936, '447')
# Group name: (13937, '447')
# Group name: (13938, '447')
# Group name: (13939, '447')
# Group name: (13940, '447,448')
# Group name: (13941, '447,448')
# Group name: (13942, '448')
# Group name: (13943, '448')
# Group name: (13944, '448')
# Group name: (13945, '448,449')
# Group name: (13946, '448,449')
# Group name: (13947, '449')
# Group name: (13948, '449')
# Group name: (13949, '449,450')
# Group name: (13950, '449,450')
# Group name: (13951, '450')
# Group name: (13952, '450')
# Group name: (13953, '450,451')
# Group name: (13954, '450,451')
# Group name: (13955, '451')
# Group name: (13956, '451')
# Group name: (13957, '451')
# Group name: (13958, '451')
# Group name: (13959, '451,452')
# Group name: (13960, '451,452')
# Group name: (13961, '452')
# Group name: (13962, '452')
# Group name: (13963, '452')
# Group name: (13964, '452')
# Group name: (13965, '452,453')
# Group name: (13966, '452,453')
# Group name: (13967, '453')
# Group name: (13968, '453')
# Group name: (13969, '453')
# Group name: (13970, '453')
# Group name: (13971, '453')
# Group name: (13972, '453')
# Group name: (13973, '453')
# Group name: (13974, '453')
# Group name: (13975, '453')
# Group name: (13976, '453')
# Group name: (13977, '453')
# Group name: (13978, '453')
# Group name: (13979, '453')
# Group name: (13980, '453')
# Group name: (13981, '453')
# Group name: (13982, '453')
# Group name: (13983, '453')
# Group name: (13984, '453')
# Group name: (13985, '453')
# Group name: (13986, '453')

# %%
contact_data= pd.read_csv("/Users/shangyu/Documents/GitHub/tactileGestureDetection/DATA/tactile_dataset.csv")
contact_counts = contact_data['block_id'].nunique()
print(f"there are {contact_counts} contact block")
# Out:
# there are 511 contact block

# %%
# 单个文件验证
